# %%
# Commento

# %%
import pandas as pd
percorso_istat = "../../01_Data/Raw_Data/istat_incidenti_raw.csv"
percorso_situas = "../../01_Data/Raw_Data/Comuni - Dimensione Data Indagine 31-12-2020 Stampa 21062026185720.csv"

# %%
#
df_istat = pd.read_csv(percorso_istat, dtype={'REF_AREA': str})
df_situas = pd.read_csv(percorso_situas, sep=';', dtype={'Codice Comune (alfanumerico)': str})

# %%
display(df_istat.head(3))

print("\n--------------------------------------------------\n")

display(df_situas.head(3))
# Out:
#           DATAFLOW FREQ REF_AREA DATA_TYPE RESULT  TIME_PERIOD  OBS_VALUE  \
# 0  IT1:41_983(1.0)    A   001001   KILLINJ      F         2001         10
# 1  IT1:41_983(1.0)    A   001001   KILLINJ      F         2002         10
# 2  IT1:41_983(1.0)    A   001001   KILLINJ      F         2003          7
#
#    OBS_STATUS  NOTE_DS  NOTE_REF_AREA  NOTE_DATA_TYPE  NOTE_RESULT  \
# 0         NaN      NaN            NaN             NaN          NaN
# 1         NaN      NaN            NaN             NaN          NaN
# 2         NaN      NaN            NaN             NaN          NaN
#
#    NOTE_TIME_PERIOD  BASE_PER  UNIT_MEAS  UNIT_MULT
# 0               NaN       NaN        NaN        NaN
# 1               NaN       NaN        NaN        NaN
# 2               NaN       NaN        NaN        NaN
# --------------------------------------------------
#    Codice Ripartizione geografica  Codice Regione  Codice Provincia (Storico)  \
# 0                               1               1                           1
# 1                               1               1                           1
# 2                               1               1                           1
#
#    Codice Provincia/Uts Codice Comune (alfanumerico)  \
# 0                   201                       001001
# 1                   201                       001002
# 2                   201                       001003
#
#    Codice Comune (numerico)        Comune Comune (dizione straniera)  \
# 0                      1001         Agliè                        NaN
# 1                      1002       Airasca                        NaN
# 2                      1003  Ala di Stura                        NaN
#
#   Sigla automobilistica  Capoluogo di Provincia/Uts  Capoluogo di Regione  \
# 0                    TO                           0                     0
# 1                    TO                           0                     0
# 2                    TO                           0                     0
#
#    Popolazione legale  Anno Censimento Superficie (Kmq)  Anno (Superficie)  \
# 0                2644             2011          13,1462               2020
# 1                3819             2011          15,7393               2020
# 2                 462             2011          46,3315               2020
#
#    Popolazione residente  Anno (Popolazione residente)
# 0                   2545                          2020
# 1                   3633                          2020
# 2                    459                          2020

# %%
df_istat.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 573552 entries, 0 to 573551
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATAFLOW          573552 non-null  str
#  1   FREQ              573552 non-null  str
#  2   REF_AREA          573552 non-null  str
#  3   DATA_TYPE         573552 non-null  str
#  4   RESULT            573552 non-null  str
#  5   TIME_PERIOD       573552 non-null  int64
#  6   OBS_VALUE         573552 non-null  int64
#  7   OBS_STATUS        0 non-null       float64
#  8   NOTE_DS           0 non-null       float64
#  9   NOTE_REF_AREA     0 non-null       float64
#  10  NOTE_DATA_TYPE    0 non-null       float64
#  11  NOTE_RESULT       0 non-null       float64
#  12  NOTE_TIME_PERIOD  0 non-null       float64
#  13  BASE_PER          0 non-null       float64
#  14  UNIT_MEAS         0 non-null       float64
#  15  UNIT_MULT         0 non-null       float64
# dtypes: float64(9), int64(2), str(5)
# memory usage: 70.0 MB

# %%
df_situas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7903 entries, 0 to 7902
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Codice Ripartizione geografica  7903 non-null   int64
#  1   Codice Regione                  7903 non-null   int64
#  2   Codice Provincia (Storico)      7903 non-null   int64
#  3   Codice Provincia/Uts            7903 non-null   int64
#  4   Codice Comune (alfanumerico)    7903 non-null   str
#  5   Codice Comune (numerico)        7903 non-null   int64
#  6   Comune                          7902 non-null   str
#  7   Comune (dizione straniera)      124 non-null    str
#  8   Sigla automobilistica           7811 non-null   str
#  9   Capoluogo di Provincia/Uts      7903 non-null   int64
#  10  Capoluogo di Regione            7903 non-null   int64
#  11  Popolazione legale              7903 non-null   int64
#  12  Anno Censimento                 7903 non-null   int64
#  13  Superficie (Kmq)                7903 non-null   str
#  14  Anno (Superficie)               7903 non-null   int64
#  15  Popolazione residente           7903 non-null   int64
#  16  Anno (Popolazione residente)    7903 non-null   int64
# dtypes: int64(12), str(5)
# memory usage: 1.0 MB

# %%
colonne_utili_istat = ['REF_AREA', 'DATA_TYPE', 'RESULT', 'TIME_PERIOD', 'OBS_VALUE']

df_istat_clean = df_istat[colonne_utili_istat]

df_istat_clean = df_istat_clean.rename(columns={
    'REF_AREA': 'Codice_Comune',
    'DATA_TYPE': 'Tipo_Dato',
    'TIME_PERIOD': 'Anno',
    'OBS_VALUE': 'N. incidenti'
})

display(df_istat_clean.head(3))
# Out:
#   Codice_Comune Tipo_Dato RESULT  Anno  N. incidenti
# 0        001001   KILLINJ      F  2001            10
# 1        001001   KILLINJ      F  2002            10
# 2        001001   KILLINJ      F  2003             7

# %%
df_situas['Superficie (Kmq)'] = df_situas['Superficie (Kmq)'].str.replace('.', '', regex=False).str.replace(',', '.', regex=False).astype(float)

colonne_utili_situas = [
    'Codice Comune (alfanumerico)', 
    'Comune', 
    'Popolazione residente', 
    'Superficie (Kmq)'
]
df_situas_clean = df_situas[colonne_utili_situas]

df_situas_clean = df_situas_clean.rename(columns={
    'Codice Comune (alfanumerico)': 'Codice_Comune',
    'Comune': 'Nome_Comune',
    'Popolazione residente': 'Popolazione',
    'Superficie (Kmq)': 'Superficie_Kmq'
})

display(df_situas_clean.head(3))
# Out:
#   Codice_Comune   Nome_Comune  Popolazione  Superficie_Kmq
# 0        001001         Agliè         2545         13.1462
# 1        001002       Airasca         3633         15.7393
# 2        001003  Ala di Stura          459         46.3315

# %%
df_merged = pd.merge(df_istat_clean, df_situas_clean, on='Codice_Comune', how='inner')
df_merged.shape[1]
# Out:
# 8

# %%
display(df_merged.head())
# Out:
#   Codice_Comune Tipo_Dato RESULT  Anno  N. incidenti Nome_Comune  Popolazione  \
# 0        001001   KILLINJ      F  2001            10       Agliè         2545
# 1        001001   KILLINJ      F  2002            10       Agliè         2545
# 2        001001   KILLINJ      F  2003             7       Agliè         2545
# 3        001001   KILLINJ      F  2004            13       Agliè         2545
# 4        001001   KILLINJ      F  2005             2       Agliè         2545
#
#    Superficie_Kmq
# 0         13.1462
# 1         13.1462
# 2         13.1462
# 3         13.1462
# 4         13.1462

# %%
# controllo
df_situas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7903 entries, 0 to 7902
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Codice Ripartizione geografica  7903 non-null   int64
#  1   Codice Regione                  7903 non-null   int64
#  2   Codice Provincia (Storico)      7903 non-null   int64
#  3   Codice Provincia/Uts            7903 non-null   int64
#  4   Codice Comune (alfanumerico)    7903 non-null   str
#  5   Codice Comune (numerico)        7903 non-null   int64
#  6   Comune                          7902 non-null   str
#  7   Comune (dizione straniera)      124 non-null    str
#  8   Sigla automobilistica           7811 non-null   str
#  9   Capoluogo di Provincia/Uts      7903 non-null   int64
#  10  Capoluogo di Regione            7903 non-null   int64
#  11  Popolazione legale              7903 non-null   int64
#  12  Anno Censimento                 7903 non-null   int64
#  13  Superficie (Kmq)                7903 non-null   float64
#  14  Anno (Superficie)               7903 non-null   int64
#  15  Popolazione residente           7903 non-null   int64
#  16  Anno (Popolazione residente)    7903 non-null   int64
# dtypes: float64(1), int64(12), str(4)
# memory usage: 1.0 MB

# %%
# controllo
df_merged.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 548685 entries, 0 to 548684
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Codice_Comune   548685 non-null  str
#  1   Tipo_Dato       548685 non-null  str
#  2   RESULT          548685 non-null  str
#  3   Anno            548685 non-null  int64
#  4   N. incidenti    548685 non-null  int64
#  5   Nome_Comune     548613 non-null  str
#  6   Popolazione     548685 non-null  int64
#  7   Superficie_Kmq  548685 non-null  float64
# dtypes: float64(1), int64(3), str(4)
# memory usage: 33.5 MB

# %%
df_pivot = df_merged.pivot_table(
    index=['Codice_Comune', 'Nome_Comune', 'Popolazione', 'Superficie_Kmq', 'Anno'],
    columns='RESULT',
    values='N. incidenti',
    aggfunc='sum'
).reset_index()

# %%
df_pivot = df_pivot.rename(columns={
    '9': 'Totale_Incidenti',
    'F': 'Feriti',
    'M': 'Morti'
})

# %%
display(df_pivot.head())
# Out:
# RESULT Codice_Comune Nome_Comune  Popolazione  Superficie_Kmq  Anno  \
# 0             001001       Agliè         2545         13.1462  2001
# 1             001001       Agliè         2545         13.1462  2002
# 2             001001       Agliè         2545         13.1462  2003
# 3             001001       Agliè         2545         13.1462  2004
# 4             001001       Agliè         2545         13.1462  2005
#
# RESULT  Totale_Incidenti  Feriti  Morti
# 0                      5      10      0
# 1                      5      10      0
# 2                      4       7      0
# 3                      9      13      0
# 4                      2       2      0

# %%
# Qua ho voluto eseguire un filtro temporale per selezionare solo gli anni che mi interessavano.
# Le giustificazioni sono: ----------------
anni_recenti = [2019, 2020, 2021, 2022, 2023]
df_finale = pd.DataFrame()
for anno in anni_recenti:
    df_temp = df_pivot[df_pivot['Anno'] == anno]
    df_finale = pd.concat([df_finale, df_temp])

df_finale.index = pd.RangeIndex(len(df_finale.index))
df_finale = df_finale.dropna().copy()

display(df_finale.head())
# Out:
# RESULT Codice_Comune      Nome_Comune  Popolazione  Superficie_Kmq  Anno  \
# 0             001001            Agliè         2545         13.1462  2019
# 1             001002          Airasca         3633         15.7393  2019
# 2             001003     Ala di Stura          459         46.3315  2019
# 3             001004  Albiano d'Ivrea         1638         11.7314  2019
# 4             001006           Almese         6355         17.8756  2019
#
# RESULT  Totale_Incidenti  Feriti  Morti
# 0                      3       5      0
# 1                      6      12      0
# 2                      0       0      0
# 3                      3       3      1
# 4                      4       7      0

# %%
# Ho voluto anche se non ancora del tutto puliiti, esportare questi dati con il filtro temporale per
# fare alcune verifiche di controllo. (scommentare per eseguire)
# percorso_export = "../../01_Data/Clean_Data/istat_filtrato_2019_2023.csv"
# df_finale.to_csv(percorso_export, index=False)

# %%
df_finale['Tasso_Incidenti_10k'] = (df_finale['Totale_Incidenti'] / df_finale['Popolazione']) * 10000
df_finale['Densita_Incidenti_Kmq'] = df_finale['Totale_Incidenti'] / df_finale['Superficie_Kmq']

df_finale['Tasso_Incidenti_10k'] = df_finale['Tasso_Incidenti_10k'].round(2)
df_finale['Densita_Incidenti_Kmq'] = df_finale['Densita_Incidenti_Kmq'].round(2)

display(df_finale.head())
# Out:
# RESULT Codice_Comune      Nome_Comune  Popolazione  Superficie_Kmq  Anno  \
# 0             001001            Agliè         2545         13.1462  2019
# 1             001002          Airasca         3633         15.7393  2019
# 2             001003     Ala di Stura          459         46.3315  2019
# 3             001004  Albiano d'Ivrea         1638         11.7314  2019
# 4             001006           Almese         6355         17.8756  2019
#
# RESULT  Totale_Incidenti  Feriti  Morti  Tasso_Incidenti_10k  \
# 0                      3       5      0                11.79
# 1                      6      12      0                16.52
# 2                      0       0      0                 0.00
# 3                      3       3      1                18.32
# 4                      4       7      0                 6.29
#
# RESULT  Densita_Incidenti_Kmq
# 0                        0.23
# 1                        0.38
# 2                        0.00
# 3                        0.26
# 4                        0.22

# %%
percorso_export_finale = "../../01_Data/Clean_Data/istat_incidenti_pulito_2019_2023.csv"
df_finale.to_csv(percorso_export_finale, index=False)
